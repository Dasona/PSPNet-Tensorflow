# %%
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore', '.*')

# %%
from IPython import display

# %%
import cStringIO as StringIO
from PIL import Image

# %%
import numpy as np
import matplotlib.pyplot as pl
from path import Path
import pandas as pd

# %%
img = pl.imread('HHA.png')
Ho = img[:,:,0]
He = img[:,:,1]
A = img[:,:,2]
pl.imshow(Ho); pl.axis('off'); pl.title('Horizontal Disparity'); pl.show()
pl.imshow(He); pl.axis('off'); pl.title('Height above ground'); pl.show()
pl.imshow(A); pl.axis('off'); pl.title('Angle with gravity'); pl.show()
